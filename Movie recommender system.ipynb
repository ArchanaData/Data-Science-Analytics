# %% [markdown]
# # Content based movie recommender system

# %% [markdown]
# project flow: data- preprocessing- build ML model- create website- deploy website

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_credits.csv')
credits = pd.read_csv('tmdb_5000_movies.csv')

# %%
movies.sample(5)
# Out:
#       movie_id                                             title  \
# 3891      1430                             Bowling for Columbine
# 4350      1781                             An Inconvenient Truth
# 1807     36355                                           Flipper
# 3472     12509                                           Pollock
# 241     308531  Teenage Mutant Ninja Turtles: Out of the Shadows
#
#                                                    cast  \
# 3891  [{"cast_id": 2, "character": "Himself", "credi...
# 4350  [{"cast_id": 2, "character": "Himself", "credi...
# 1807  [{"cast_id": 1, "character": "Sandy Ricks", "c...
# 3472  [{"cast_id": 1, "character": "Jackson Pollock"...
# 241   [{"cast_id": 3, "character": "April O'Neil", "...
#
#                                                    crew
# 3891  [{"credit_id": "562fbe5bc3a3681b5c00dc04", "de...
# 4350  [{"credit_id": "52fe4314c3a36847f8038c0f", "de...
# 1807  [{"credit_id": "546379a80e0a2678100024c1", "de...
# 3472  [{"credit_id": "52fe44f19251416c75046447", "de...
# 241   [{"credit_id": "551b8ef6c3a3687682001b51", "de...

# %%
movies.shape
# Out:
# (4803, 4)

# %%
credits.sample(5)
# Out:
#         budget                                             genres  \
# 593   70000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 1592  30000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 1438  27000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 791   58000000  [{"id": 12, "name": "Adventure"}, {"id": 27, "...
# 4609         0                     [{"id": 35, "name": "Comedy"}]
#
#                               homepage      id  \
# 593     http://www.thedilemmamovie.com   44564
# 1592                               NaN    4105
# 1438                               NaN     849
# 791   http://www.goosebumps-movie.com/  257445
# 4609                               NaN   11956
#
#                                                keywords original_language  \
# 593   [{"id": 596, "name": "adultery"}, {"id": 1326,...                en
# 1592  [{"id": 233, "name": "japan"}, {"id": 1794, "n...                en
# 1438  [{"id": 4152, "name": "kingdom"}, {"id": 10016...                en
# 791   [{"id": 818, "name": "based on novel"}, {"id":...                en
# 4609  [{"id": 90, "name": "paris"}, {"id": 977, "nam...                fr
#
#                original_title  \
# 593               The Dilemma
# 1592               Black Rain
# 1438                    Krull
# 791                Goosebumps
# 4609  Chacun Cherche Son Chat
#
#                                                overview  popularity  \
# 593   Longtime friends Ronny and Nick are partners i...   14.780634
# 1592  Two New York cops get involved in a gang war b...   11.196020
# 1438  A prince and a fellowship of companions set ou...    9.904881
# 791   A teenager teams up with the daughter of young...   45.351617
# 4609  When Chloe (Garance Clavel), a young Parisian,...    1.410387
#
#                                    production_companies  \
# 593   [{"name": "Imagine Entertainment", "id": 23}, ...
# 1592  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 1438  [{"name": "Columbia Pictures Corporation", "id...
# 791   [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 4609  [{"name": "Vertigo Productions", "id": 2756}, ...
#
#                                    production_countries release_date  \
# 593   [{"iso_3166_1": "US", "name": "United States o...   2011-01-13
# 1592  [{"iso_3166_1": "US", "name": "United States o...   1989-09-22
# 1438  [{"iso_3166_1": "ES", "name": "Spain"}, {"iso_...   1983-07-29
# 791   [{"iso_3166_1": "AU", "name": "Australia"}, {"...   2015-08-05
# 4609           [{"iso_3166_1": "FR", "name": "France"}]   1996-04-03
#
#         revenue  runtime                                   spoken_languages  \
# 593    67112664    111.0           [{"iso_639_1": "en", "name": "English"}]
# 1592   45892212    125.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1438   16519460    117.0           [{"iso_639_1": "en", "name": "English"}]
# 791   158162788    103.0           [{"iso_639_1": "en", "name": "English"}]
# 4609          0     91.0     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"}]
#
#         status                                            tagline  \
# 593   Released  Two best friends. Nothing could come between t...
# 1592  Released  Their country. Their laws. Their game. His rules.
# 1438  Released       A world light-years beyond your imagination.
# 791   Released                             The stories are alive.
# 4609  Released                            No man. No job. No cat.
#
#                     title  vote_average  vote_count
# 593           The Dilemma           5.2         304
# 1592           Black Rain           6.2         243
# 1438                Krull           5.8         129
# 791            Goosebumps           6.2         995
# 4609  When the Cat's Away           6.1          16

# %%
credits.shape
# Out:
# (4803, 20)

# %%
movies = movies.merge(credits,on='title')

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)
movies.sample(5)
# Out:
#       movie_id                      title  \
# 3183      8272                The Savages
# 1261     16643  Life or Something Like It
# 3037     14729            The Long Riders
# 338      10733                  The Alamo
# 1086      9381               Babylon A.D.
#
#                                                overview  \
# 3183  A sister and brother face the realities of fam...
# 1261  A reporter Lanie Kerrigan interviews a psychic...
# 3037  The origins, exploits and the ultimate fate of...
# 338   Based on the 1836 standoff between a group of ...
# 1086  In Babylon A.D Vin Diesel stars as a veteran-t...
#
#                                               genres  \
# 3183                                         [Drama]
# 1261                        [Comedy, Drama, Romance]
# 3037                              [Western, History]
# 338                          [Western, History, War]
# 1086  [Action, Adventure, Science Fiction, Thriller]
#
#                                                keywords  \
# 3183  [father son relationship, depression, parents ...
# 1261                                                 []
# 3037  [brother brother relationship, jesse james, co...
# 338          [texas, officer, uprising, alamo, mexican]
# 1086  [submarine, baby, secret, future, mercenary, p...
#
#                                                    cast                 crew
# 3183  [Laura Linney, Philip Seymour Hoffman, Philip ...     [Tamara Jenkins]
# 1261      [Angelina Jolie, Edward Burns, Tony Shalhoub]      [Stephen Herek]
# 3037  [David Carradine, Keith Carradine, Robert Carr...        [Walter Hill]
# 338    [Dennis Quaid, Billy Bob Thornton, Jason Patric]   [John Lee Hancock]
# 1086       [Vin Diesel, Michelle Yeoh, Mélanie Thierry]  [Mathieu Kassovitz]

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]])

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# 744

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Inception')
# Out:
# Duplex
# The Helix... Loaded
# Star Trek II: The Wrath of Khan
# Timecop
# Chicago Overcoat
